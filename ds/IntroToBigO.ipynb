# %%
def sum1(n):
    final_sum = 0

    for x in range(n+1):
        final_sum +=x

    return final_sum

# %%
def sum2(n):
    return (n*(n+1)/2)

# %%
# %timeit sum1(100)
# Out:
# 3.64 µs ± 6.82 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit sum2(100)
# Out:
# 111 ns ± 0.287 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
